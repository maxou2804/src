tehran=json.loads(tehran)

atlanta='{"x":[14.151,14.805,19.02,19.585,20.288,20.717,20.971,21.4,21.712,22.083,22.278,22.317,22.532,22.59,22.98,23.859,24.444,25.459,26.102,30.122,32.132,35.751],"y":[79.854,84.709,108.981,110.194,115.049,117.718,120.631,122.573,125.243,140.777,129.126,135.68,132.039,143.204,144.175,148.301,148.786,152.427,154.126,176.942,189.563,207.282]}'
atlanta=json.loads(atlanta)

lasvegas='{"x":[0.14,0.166,0.334,0.358,0.381,0.437,0.474,0.512,0.545,0.611,0.681,0.728,0.78,0.853,0.914,0.959,0.995,1.035,1.07,1.097,1.124,1.163,1.192,1.228,1.265,1.305,1.351,1.404,1.45,1.501],"y":[88.472,104.558,228.954,250.402,265.416,307.239,332.976,354.424,369.437,410.188,448.794,469.169,492.761,529.223,557.105,595.71,612.869,632.172,645.04,657.909,666.488,675.067,687.936,694.37,698.66,700.804,704.021,708.311,710.456,710.456]}'
lasvegas=json.loads(lasvegas)

# plt.figure()
# plt.loglog(ningbo['x'],ningbo['y'],'o')
# print('Ningbo:')
# print(np.polyfit(np.log10(ningbo['x']),np.log10(ningbo['y']),1)[0])


# plt.figure()
# plt.loglog(chengdu_deyang['x'],chengdu_deyang['y'],'o')
# print('Chengdu')
# print(np.polyfit(np.log10(chengdu_deyang['x']),np.log10(chengdu_deyang['y']),1)[0])

# plt.figure()
# plt.loglog(beijing['x'],beijing['y'],'o')
# print('Beijing')
# print(np.polyfit(np.log10(beijing['x']),np.log10(beijing['y']),1)[0])


# plt.figure()
# plt.loglog(changzhou['x'],changzhou['y'],'o')
# print('Changzhou')
# print(np.polyfit(np.log10(changzhou['x']),np.log10(changzhou['y']),1)[0])


# plt.figure()
# plt.loglog(bengalore['x'],bengalore['y'],'o')
# print('Bengalore')
# print(np.polyfit(np.log10(bengalore['x']),np.log10(bengalore['y']),1)[0])

# plt.figure()
# plt.loglog(kolkata['x'],kolkata['y'],'o')
# print('Kolkata')
# print(np.polyfit(np.log10(kolkata['x']),np.log10(kolkata['y']),1)[0])


# plt.figure()
# plt.loglog(paris['x'],paris['y'],'o')
# print('Paris')
# print(np.polyfit(np.log10(paris['x']),np.log10(paris['y']),1)[0])


# plt.figure()
# plt.loglog(bangkok['x'],bangkok['y'],'o')
# print('Bangkok')
# print(np.polyfit(np.log10(bangkok['x']),np.log10(bangkok['y']),1)[0])

# plt.figure()
# plt.loglog(cairo['x'],cairo['y'],'o')
# print('Cairo')
# print(np.polyfit(np.log10(cairo['x']),np.log10(cairo['y']),1)[0])


# plt.figure()
# plt.loglog(guatemala_city['x'],guatemala_city['y'],'o')
# print('Guatemala City')
# print(np.polyfit(np.log10(guatemala_city['x']),np.log10(guatemala_city['y']),1)[0])

# plt.figure()
# plt.loglog(johannesburg['x'],johannesburg['y'],'o')
# print('Johannesburg')
# print(np.polyfit(np.log10(johannesburg['x']),np.log10(johannesburg['y']),1)[0])

# plt.figure()
# plt.loglog(london['x'],london['y'],'o')
# print('London')
# print(np.polyfit(np.log10(london['x']),np.log10(london['y']),1)[0])

# plt.figure()
# plt.loglog(mexico_city['x'],mexico_city['y'],'o')
# print('Mexico City')
# print(np.polyfit(np.log10(mexico_city['x']),np.log10(mexico_city['y']),1)[0])

# plt.figure()
# plt.loglog(nairobi['x'],nairobi['y'],'o')
# print('Nairobo')
# print(np.polyfit(np.log10(nairobi['x']),np.log10(nairobi['y']),1)[0])

# plt.figure()
# plt.loglog(santiago['x'],santiago['y'],'o')
# print('Santiago')
# print(np.polyfit(np.log10(santiago['x']),np.log10(santiago['y']),1)[0])

# plt.figure()
# plt.loglog(sao_paulo['x'],sao_paulo['y'],'o')
# print('Sao Paulo')
# print(np.polyfit(np.log10(sao_paulo['x']),np.log10(sao_paulo['y']),1)[0])

# plt.figure()
# plt.loglog(tehran['x'],tehran['y'],'o')
# print('Teheran')
# print(np.polyfit(np.log10(tehran['x']),np.log10(tehran['y']),1)[0])

# plt.figure()
# plt.loglog(atlanta['x'],atlanta['y'],'o')
# print('Atlanta')
# print(np.polyfit(np.log10(atlanta['x']),np.log10(atlanta['y']),1)[0])

# plt.figure()
# plt.loglog(lasvegas['x'],lasvegas['y'],'o')
# print('Las Vegas')
# print(np.polyfit(np.log10(lasvegas['x']),np.log10(lasvegas['y']),1)[0])




kappa=np.array([np.polyfit(np.log10(ningbo['x']),np.log10(ningbo['y']),1)[0],np.polyfit(np.log10(chengdu_deyang['x']),np.log10(chengdu_deyang['y']),1)[0],np.polyfit(np.log10(beijing['x']),np.log10(beijing['y']),1)[0],
np.polyfit(np.log10(changzhou['x']),np.log10(changzhou['y']),1)[0],np.polyfit(np.log10(bengalore['x']),np.log10(bengalore['y']),1)[0], np.polyfit(np.log10(kolkata['x']),np.log10(kolkata['y']),1)[0],
np.polyfit(np.log10(paris['x']),np.log10(paris['y']),1)[0],np.polyfit(np.log10(bangkok['x']),np.log10(bangkok['y']),1)[0],np.polyfit(np.log10(cairo['x']),np.log10(cairo['y']),1)[0],
np.polyfit(np.log10(guatemala_city['x']),np.log10(guatemala_city['y']),1)[0],np.polyfit(np.log10(johannesburg['x']),np.log10(johannesburg['y']),1)[0],
np.polyfit(np.log10(london['x']),np.log10(london['y']),1)[0],np.polyfit(np.log10(mexico_city['x']),np.log10(mexico_city['y']),1)[0],np.polyfit(np.log10(nairobi['x']),np.log10(nairobi['y']),1)[0],
np.polyfit(np.log10(santiago['x']),np.log10(santiago['y']),1)[0],np.polyfit(np.log10(sao_paulo['x']),np.log10(sao_paulo['y']),1)[0],np.polyfit(np.log10(tehran['x']),np.log10(tehran['y']),1)[0],
np.polyfit(np.log10(atlanta['x']),np.log10(atlanta['y']),1)[0],np.polyfit(np.log10(lasvegas['x']),np.log10(lasvegas['y']),1)[0]])


df = pd.DataFrame(kappa)
df.to_csv("kappa.csv")
